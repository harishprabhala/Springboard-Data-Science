# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/harishprabhala/Downloads/amazon-meta.txt.gz', sep= ' ', compression='gzip', error_bad_lines=False)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# ...

# %%
data.head()
# Out:
#        #        Full   information    about Amazon Share  the Love products
# 0  Total      items:        548552      NaN    NaN   NaN  NaN  NaN      NaN
# 1    Id:         NaN           NaN        0    NaN   NaN  NaN  NaN      NaN
# 2  ASIN:  0771044445           NaN      NaN    NaN   NaN  NaN  NaN      NaN
# 3    NaN         NaN  discontinued  product    NaN   NaN  NaN  NaN      NaN
# 4    Id:         NaN           NaN        1    NaN   NaN  NaN  NaN      NaN

# %%
#with open('/Users/harishprabhala/Downloads/amazon-meta.txt', ) as fp:
#    for line in fp:
#        print (line)

# %%
df = pd.read_csv('/Users/harishprabhala/Downloads/amazon-meta.txt', chunksize=1, header=None, encoding='utf-8')

# %%
print(df)

# %%
## The project is taking way more time than anticipated. Challenges with reading the data file
